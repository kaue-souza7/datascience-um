# %%
import pandas as pd
import numpy as np

import scipy

# %% [markdown]
# # Hipotese alternativa e Hipotese nula

# %%
df = pd.read_csv('DataOfModule4/grades.csv')
df.head(2)
# Out:
#                              student_id  assignment1_grade  \
# 0  B73F2C11-70F0-E37D-8B10-1D20AFED50B1          92.733946
# 1  98A0FAE0-A19A-13D2-4BB5-CFBFD94031D1          86.790821
#
#           assignment1_submission  assignment2_grade  \
# 0  2015-11-02 06:55:34.282000000          83.030552
# 1  2015-11-29 14:57:44.429000000          86.290821
#
#           assignment2_submission  assignment3_grade  \
# 0  2015-11-09 02:22:58.938000000          67.164441
# 1  2015-12-06 17:41:18.449000000          69.772657
#
#           assignment3_submission  assignment4_grade  \
# 0  2015-11-12 08:58:33.998000000          53.011553
# 1  2015-12-10 08:54:55.904000000          55.098125
#
#           assignment4_submission  assignment5_grade  \
# 0  2015-11-16 01:21:24.663000000          47.710398
# 1  2015-12-13 17:32:30.941000000          49.588313
#
#           assignment5_submission  assignment6_grade  \
# 0  2015-11-20 13:24:59.692000000          38.168318
# ...

# %%
early_finishers = df[pd.to_datetime(df['assignment1_submission']) < '2016']
late_finishers = df[pd.to_datetime(df['assignment1_submission']) > '2016']
# ORRRR
# late_finishers=df[~df.index.isin(early_finishers.index)]
 
late_finishers.head()
# Out:
#                              student_id  assignment1_grade  \
# 2  D0F62040-CEB0-904C-F563-2F8620916C4E          85.512541
# 3  FFDF2B2C-F514-EF7F-6538-A6A53518E9DC          86.030665
# 6  3217BE3F-E4B0-C3B6-9F64-462456819CE4          87.498744
# 7  F1CB5AA1-B3DE-5460-FAFF-BE951FD38B5F          80.576090
# 9  E2C617C2-4654-622C-AB50-1550C4BE42A0          59.270882
#
#           assignment1_submission  assignment2_grade  \
# 2  2016-01-09 05:36:02.389000000          85.512541
# 3  2016-04-30 06:50:39.801000000          68.824532
# 6  2016-03-05 11:05:25.408000000          69.998995
# 7  2016-01-24 18:24:25.619000000          72.518481
# 9  2016-03-06 12:06:26.185000000          59.270882
#
#           assignment2_submission  assignment3_grade  \
# 2  2016-01-09 06:39:44.416000000          68.410033
# 3  2016-04-30 17:20:38.727000000          61.942079
# 6  2016-03-09 07:29:52.405000000          55.999196
# 7  2016-01-27 13:37:12.943000000          65.266633
# ...

# %%
early_finishers['assignment1_grade'].mean()
# Out:
# np.float64(74.94728457024304)

# %%
late_finishers['assignment1_grade'].mean()
# Out:
# np.float64(74.0450648477065)

# %%
from scipy.stats import ttest_ind

# %%
ttest_ind(early_finishers['assignment1_grade'], late_finishers['assignment1_grade'])
# Out:
# TtestResult(statistic=np.float64(1.3223540853721598), pvalue=np.float64(0.18618101101713855), df=np.float64(2313.0))

# %%
early_finishers.columns
# Out:
# Index(['student_id', 'assignment1_grade', 'assignment1_submission',
#        'assignment2_grade', 'assignment2_submission', 'assignment3_grade',
#        'assignment3_submission', 'assignment4_grade', 'assignment4_submission',
#        'assignment5_grade', 'assignment5_submission', 'assignment6_grade',
#        'assignment6_submission'],
#       dtype='object')

# %%
type(early_finishers['assignment1_grade'])
# Out:
# pandas.core.series.Series

# %%
print(ttest_ind(early_finishers['assignment1_grade'], late_finishers['assignment1_grade']))
print(ttest_ind(early_finishers['assignment2_grade'], late_finishers['assignment2_grade']))
print(ttest_ind(early_finishers['assignment3_grade'], late_finishers['assignment3_grade']))
print(ttest_ind(early_finishers['assignment4_grade'], late_finishers['assignment4_grade']))
print(ttest_ind(early_finishers['assignment5_grade'], late_finishers['assignment5_grade']))
print(ttest_ind(early_finishers['assignment6_grade'], late_finishers['assignment4_grade']))
# Out:
# TtestResult(statistic=np.float64(1.3223540853721598), pvalue=np.float64(0.18618101101713855), df=np.float64(2313.0))
# TtestResult(statistic=np.float64(1.2514717608216366), pvalue=np.float64(0.2108889627004424), df=np.float64(2313.0))
# TtestResult(statistic=np.float64(1.6133726558705392), pvalue=np.float64(0.10679998102227865), df=np.float64(2313.0))
# TtestResult(statistic=np.float64(0.049671157386456125), pvalue=np.float64(0.960388729789337), df=np.float64(2313.0))
# TtestResult(statistic=np.float64(-0.05279315545404755), pvalue=np.float64(0.9579012739746492), df=np.float64(2313.0))
# TtestResult(statistic=np.float64(-17.63619114604756), pvalue=np.float64(2.052132776761959e-65), df=np.float64(2313.0))

# %%
df1 = pd.DataFrame([np.random.random(100) for x in range(100)])
df2 = pd.DataFrame([np.random.random(100) for x in range(100)])

# %%
df1.head()
# Out:
#          0         1         2         3         4         5         6   \
# 0  0.566616  0.500283  0.192815  0.056578  0.962825  0.543796  0.463649
# 1  0.297809  0.465763  0.449084  0.314781  0.273758  0.605666  0.640018
# 2  0.771687  0.696844  0.209547  0.799833  0.184949  0.477538  0.100931
# 3  0.833706  0.343304  0.546070  0.189721  0.748266  0.720321  0.572192
# 4  0.444447  0.158519  0.785677  0.971207  0.577813  0.122755  0.464748
#
#          7         8         9   ...        90        91        92        93  \
# 0  0.599847  0.767128  0.357236  ...  0.844387  0.545594  0.084622  0.892415
# 1  0.316613  0.507547  0.738311  ...  0.399312  0.843406  0.223964  0.457958
# 2  0.571805  0.445953  0.091355  ...  0.987561  0.265309  0.523997  0.893010
# 3  0.818920  0.653422  0.100361  ...  0.905041  0.219833  0.034327  0.786260
# 4  0.866769  0.599739  0.564311  ...  0.279699  0.251484  0.859421  0.002382
#
#          94        95        96        97        98        99
# ...

# %% [markdown]
# HIPÓTESE ALTERNATIVA: Os DF são diferentes.
#
# HIPOTESE NULA: Os dois DF são iguais?
#
# p-value baixo: evidência contra a hipótese nula.
#
#
# p-value alto: pouca ou nenhuma evidência contra a hipótese nula.

# %% [markdown]
# p-value verifica se há uma diferença significativa na média da um conjunto.

# %%
def test_columns(alpha=0.1):
    num_diff=0
    for c in df1.columns:
        teststat, pvalue = list(ttest_ind(df1[c], df2[c]))
        if pvalue <= alpha:
            print(f'Col {c} is statistically significantly different at alpha={alpha}, pval={pvalue}')
            num_diff += 1
            # print(pvalue)
            # print(c)  
    # return f'Total number different columns: {num_diff / len(df1.columns) * 100}'

# %%
test_columns()
# Out:
# Col 12 is statistically significantly different at alpha=0.1, pval=0.0908990918631693
# Col 24 is statistically significantly different at alpha=0.1, pval=0.058268491264744086
# Col 26 is statistically significantly different at alpha=0.1, pval=0.0578856745907176
# Col 54 is statistically significantly different at alpha=0.1, pval=0.0519808289842204
# Col 76 is statistically significantly different at alpha=0.1, pval=0.04715764436943404
# Col 83 is statistically significantly different at alpha=0.1, pval=0.04755397787361732
# Col 90 is statistically significantly different at alpha=0.1, pval=0.05436613101524525

# %%
df2=pd.DataFrame([np.random.chisquare(df=1,size=100) for x in range(100)])
test_columns()
# Out:
# Col 0 is statistically significantly different at alpha=0.1, pval=0.05689480106607317
# Col 1 is statistically significantly different at alpha=0.1, pval=0.015165632757210029
# Col 2 is statistically significantly different at alpha=0.1, pval=2.847675598827384e-06
# Col 3 is statistically significantly different at alpha=0.1, pval=0.014194193416859733
# Col 4 is statistically significantly different at alpha=0.1, pval=0.0005060931699423228
# Col 5 is statistically significantly different at alpha=0.1, pval=9.185506750806281e-05
# Col 6 is statistically significantly different at alpha=0.1, pval=0.00016429688664218055
# Col 7 is statistically significantly different at alpha=0.1, pval=0.0004736853494690171
# Col 8 is statistically significantly different at alpha=0.1, pval=0.00016906853646695037
# Col 9 is statistically significantly different at alpha=0.1, pval=3.231014392242754e-06
# Col 10 is statistically significantly different at alpha=0.1, pval=9.144999743294058e-06
# ...
